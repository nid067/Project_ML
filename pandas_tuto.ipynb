# %%
import pandas as pd

# %% [markdown]
# Creating dataframe

# %%
df=pd.DataFrame([[1,2,3],[7,8,9],[34,67,43]],columns=["A","B","C"],index=["x","y","z"])
df.head()
df.tail(1)
# Out:
#     A   B   C
# z  34  67  43

# %%
df.index.tolist()
df.info()
df.describe()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes
# (3, 3)

# %%
df.size
# Out:
# 9

# %% [markdown]
# Working with real data

# %%
data = pd.read_csv('/content/medical_insurance.csv')
data.head()
data.tail()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 2767   47  female  45.320         1     no  southeast   8569.86180
# 2768   21  female  34.600         0     no  southwest   2020.17700
# 2769   19    male  26.030         1    yes  northwest  16450.89470
# 2770   23    male  18.715         0     no  northwest  21595.38229
# 2771   54    male  31.600         0     no  southwest   9850.43200

# %%
data.describe()
data.size
# Out:
# 19404

# %% [markdown]
# Converting csv file format to parquet file format(More efficient due to column based)

# %%
bios=pd.read_csv('/content/medical_insurance.csv')

# %%
bios.to_parquet   ## conversion to .parquet
bios.head()
bios.info()
bios['children']=bios['children'].fillna(0)
print(bios['bmi'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2772 non-null   int64
#  1   sex       2772 non-null   object
#  2   bmi       2772 non-null   float64
#  3   children  2772 non-null   int64
#  4   smoker    2772 non-null   object
#  5   region    2772 non-null   object
#  6   charges   2772 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 151.7+ KB
# 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 2767    45.320
# 2768    34.600
# 2769    26.030
# 2770    18.715
# 2771    31.600
# Name: bmi, Length: 2772, dtype: float64

# %%
## loc and iloc (for selecting data from dataframe )
bios.loc["Row1","age"] = 20

bios.iloc[:50]
# Out:
#      age     sex     bmi  children smoker     region      charges
# 0   19.0  female  27.900       0.0    yes  southwest  16884.92400
# 1   18.0    male  33.770       1.0     no  southeast   1725.55230
# 2   28.0    male  33.000       3.0     no  southeast   4449.46200
# 3   33.0    male  22.705       0.0     no  northwest  21984.47061
# 4   32.0    male  28.880       0.0     no  northwest   3866.85520
# 5   31.0  female  25.740       0.0     no  southeast   3756.62160
# 6   46.0  female  33.440       1.0     no  southeast   8240.58960
# 7   37.0  female  27.740       3.0     no  northwest   7281.50560
# 8   37.0    male  29.830       2.0     no  northeast   6406.41070
# 9   60.0  female  25.840       0.0     no  northwest  28923.13692
# 10  25.0    male  26.220       0.0     no  northeast   2721.32080
# 11  62.0  female  26.290       0.0    yes  southeast  27808.72510
# 12  23.0    male  34.400       0.0     no  southwest   1826.84300
# ...

# %% [markdown]
# iat and at are similar to loc and iloc

# %%
data.iat[5,5]
# Out:
# 'southeast'

# %%
data.sort_values(["children","sex"],ascending=False)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 71     31    male  28.50         5     no  northeast   6799.4580
# 413    25    male  23.90         5     no  southwest   5080.0960
# 425    45    male  24.31         5     no  southeast   9788.8659
# 640    33    male  42.40         5     no  southwest   6666.2430
# 877    33    male  33.44         5     no  southeast   6653.7886
# ...   ...     ...    ...       ...    ...        ...         ...
# 2743   18  female  39.82         0     no  southeast   1633.9618
# 2747   62  female  39.16         0     no  southeast  13470.8044
# 2752   45  female  35.30         0     no  southwest   7348.1420
# 2754   59  female  27.50         0     no  southwest  12233.8280
# 2768   21  female  34.60         0     no  southwest   2020.1770
#
# [2772 rows x 7 columns]

# %% [markdown]
# ## Filtering data

# %%
bios.loc[bios['charges'] > 10000].info()
bios.loc[bios['children']==3]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1292 entries, 0 to 2770
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1292 non-null   float64
#  1   sex       1292 non-null   object
#  2   bmi       1292 non-null   float64
#  3   children  1292 non-null   float64
#  4   smoker    1292 non-null   object
#  5   region    1292 non-null   object
#  6   charges   1292 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 80.8+ KB
#        age     sex     bmi  children smoker     region      charges
# 2     28.0    male  33.000       3.0     no  southeast   4449.46200
# 7     37.0  female  27.740       3.0     no  northwest   7281.50560
# 25    59.0  female  27.720       3.0     no  southeast  14001.13380
# 36    62.0  female  32.965       3.0     no  northwest  15612.19335
# 54    40.0  female  28.690       3.0     no  northwest   8059.67910
# ...

# %%
bios[bios['region'].str.contains("northwest",case=False,na=False)]    # extracting only the column containing northwest as the string
# Out:
#        age     sex     bmi  children smoker     region      charges
# 3     33.0    male  22.705       0.0     no  northwest  21984.47061
# 4     32.0    male  28.880       0.0     no  northwest   3866.85520
# 7     37.0  female  27.740       3.0     no  northwest   7281.50560
# 9     60.0  female  25.840       0.0     no  northwest  28923.13692
# 24    37.0    male  28.025       2.0     no  northwest   6203.90175
# ...    ...     ...     ...       ...    ...        ...          ...
# 2756  39.0  female  24.225       5.0     no  northwest   8965.79575
# 2761  54.0  female  35.815       3.0     no  northwest  12495.29085
# 2762  21.0  female  32.680       2.0     no  northwest  26018.95052
# 2769  19.0    male  26.030       1.0    yes  northwest  16450.89470
# 2770  23.0    male  18.715       0.0     no  northwest  21595.38229
#
# [664 rows x 7 columns]

# %%
bios['region'].str.startswith("north")
bios.iloc[:50]
# Out:
#      age     sex     bmi  children smoker     region      charges
# 0   19.0  female  27.900       0.0    yes  southwest  16884.92400
# 1   18.0    male  33.770       1.0     no  southeast   1725.55230
# 2   28.0    male  33.000       3.0     no  southeast   4449.46200
# 3   33.0    male  22.705       0.0     no  northwest  21984.47061
# 4   32.0    male  28.880       0.0     no  northwest   3866.85520
# 5   31.0  female  25.740       0.0     no  southeast   3756.62160
# 6   46.0  female  33.440       1.0     no  southeast   8240.58960
# 7   37.0  female  27.740       3.0     no  northwest   7281.50560
# 8   37.0    male  29.830       2.0     no  northeast   6406.41070
# 9   60.0  female  25.840       0.0     no  northwest  28923.13692
# 10  25.0    male  26.220       0.0     no  northeast   2721.32080
# 11  62.0  female  26.290       0.0    yes  southeast  27808.72510
# 12  23.0    male  34.400       0.0     no  southwest   1826.84300
# ...

# %% [markdown]
# Query() to fetch the particular dataset based on the condition

# %%
bios.query('children > 2 and sex == "male" and region == "southeast"')    # syntax error is there and corrected
# Out:
#        age   sex    bmi  children smoker     region      charges
# 2     28.0  male  33.00       3.0     no  southeast   4449.46200
# 61    25.0  male  33.66       4.0     no  southeast   4504.66240
# 69    28.0  male  23.98       3.0    yes  southeast  17663.14420
# 225   55.0  male  33.88       3.0     no  southeast  11987.16820
# 265   46.0  male  42.35       3.0    yes  southeast  46151.12450
# 289   52.0  male  26.40       3.0     no  southeast  25992.82104
# 312   43.0  male  35.97       3.0    yes  southeast  42124.51530
# 356   46.0  male  43.89       3.0     no  southeast   8944.11510
# 408   38.0  male  21.12       3.0     no  southeast   6652.52880
# 425   45.0  male  24.31       5.0     no  southeast   9788.86590
# 435   60.0  male  33.11       3.0     no  southeast  13919.82290
# 639   56.0  male  33.66       4.0     no  southeast  12949.15540
# 660   37.0  male  46.53       3.0     no  southeast   6435.62370
# ...

# %% [markdown]
# ### Adding/Removing columns

# %%
bios['new_charges'] = 0

# %%
bios.head()
# Out:
#     age     sex     bmi  children smoker     region      charges  new_charges
# 0  19.0  female  27.900       0.0    yes  southwest  16884.92400            0
# 1  18.0    male  33.770       1.0     no  southeast   1725.55230            0
# 2  28.0    male  33.000       3.0     no  southeast   4449.46200            0
# 3  33.0    male  22.705       0.0     no  northwest  21984.47061            0
# 4  32.0    male  28.880       0.0     no  northwest   3866.85520            0

# %% [markdown]
# ### Adding specific value for different columns based on condition

# %%
import numpy as np

bios['new_charges']=np.where(bios['smoker']=='yes',bios['charges']+5000,bios['charges']+1000)

# %%
bios.head()
bios.tail()
# Out:
#        age     sex     bmi  children smoker     region      charges  \
# 2768  21.0  female  34.600       0.0     no  southwest   2020.17700
# 2769  19.0    male  26.030       1.0    yes  northwest  16450.89470
# 2770  23.0    male  18.715       0.0     no  northwest  21595.38229
# 2771  54.0    male  31.600       0.0     no  southwest   9850.43200
# Row1  20.0     NaN     NaN       NaN    NaN        NaN          NaN
#
#       new_charges
# 2768   3020.17700
# 2769  21450.89470
# 2770  22595.38229
# 2771  10850.43200
# Row1          NaN

# %% [markdown]
# ## for deletion of the table
# drop()-deletes the row if index is specified and deletes column if condition is
#     drop(column=['col_name'])

# %% [markdown]
# Making backup data_var to prevent data lose during the usage of inplace=True

# %%
data_backup=bios.copy()
data_backup
# Out:
#        age     sex     bmi  children smoker     region      charges  \
# 0     19.0  female  27.900       0.0    yes  southwest  16884.92400
# 1     18.0    male  33.770       1.0     no  southeast   1725.55230
# 2     28.0    male  33.000       3.0     no  southeast   4449.46200
# 3     33.0    male  22.705       0.0     no  northwest  21984.47061
# 4     32.0    male  28.880       0.0     no  northwest   3866.85520
# ...    ...     ...     ...       ...    ...        ...          ...
# 2768  21.0  female  34.600       0.0     no  southwest   2020.17700
# 2769  19.0    male  26.030       1.0    yes  northwest  16450.89470
# 2770  23.0    male  18.715       0.0     no  northwest  21595.38229
# 2771  54.0    male  31.600       0.0     no  southwest   9850.43200
# Row1  20.0     NaN     NaN       NaN    NaN        NaN          NaN
#
#       new_charges
# 0     21884.92400
# 1      2725.55230
# 2      5449.46200
# 3     22984.47061
# 4      4866.85520
# ...           ...
# ...

# %%
 ## bios.drop(4 ,inplace=True)  ## inplace parameter makes the changes permanent(Once Deleted cannot be recovered so create a backup or reload the data)
 bios.drop(columns=['new_charges'])
# Out:
#        age     sex     bmi  children smoker     region      charges
# 0     19.0  female  27.900       0.0    yes  southwest  16884.92400
# 1     18.0    male  33.770       1.0     no  southeast   1725.55230
# 2     28.0    male  33.000       3.0     no  southeast   4449.46200
# 3     33.0    male  22.705       0.0     no  northwest  21984.47061
# 4     32.0    male  28.880       0.0     no  northwest   3866.85520
# ...    ...     ...     ...       ...    ...        ...          ...
# 2768  21.0  female  34.600       0.0     no  southwest   2020.17700
# 2769  19.0    male  26.030       1.0    yes  northwest  16450.89470
# 2770  23.0    male  18.715       0.0     no  northwest  21595.38229
# 2771  54.0    male  31.600       0.0     no  southwest   9850.43200
# Row1  20.0     NaN     NaN       NaN    NaN        NaN          NaN
#
# [2773 rows x 7 columns]

# %%
bios.head(10)
# Out:
#     age     sex     bmi  children smoker     region      charges  new_charges
# 0  19.0  female  27.900       0.0    yes  southwest  16884.92400  21884.92400
# 1  18.0    male  33.770       1.0     no  southeast   1725.55230   2725.55230
# 2  28.0    male  33.000       3.0     no  southeast   4449.46200   5449.46200
# 3  33.0    male  22.705       0.0     no  northwest  21984.47061  22984.47061
# 4  32.0    male  28.880       0.0     no  northwest   3866.85520   4866.85520
# 5  31.0  female  25.740       0.0     no  southeast   3756.62160   4756.62160
# 6  46.0  female  33.440       1.0     no  southeast   8240.58960   9240.58960
# 7  37.0  female  27.740       3.0     no  northwest   7281.50560   8281.50560
# 8  37.0    male  29.830       2.0     no  northeast   6406.41070   7406.41070
# 9  60.0  female  25.840       0.0     no  northwest  28923.13692  29923.13692

# %%
data_backup['diff_in_charges']=data_backup['new_charges']-data_backup['charges']

# %%
data_backup.head(8)
# Out:
#     age     sex     bmi  children smoker     region      charges  new_charges  \
# 0  19.0  female  27.900       0.0    yes  southwest  16884.92400  21884.92400
# 1  18.0    male  33.770       1.0     no  southeast   1725.55230   2725.55230
# 2  28.0    male  33.000       3.0     no  southeast   4449.46200   5449.46200
# 3  33.0    male  22.705       0.0     no  northwest  21984.47061  22984.47061
# 4  32.0    male  28.880       0.0     no  northwest   3866.85520   4866.85520
# 5  31.0  female  25.740       0.0     no  southeast   3756.62160   4756.62160
# 6  46.0  female  33.440       1.0     no  southeast   8240.58960   9240.58960
# 7  37.0  female  27.740       3.0     no  northwest   7281.50560   8281.50560
#
#    diff_in_charges
# 0           5000.0
# 1           1000.0
# 2           1000.0
# 3           1000.0
# 4           1000.0
# 5           1000.0
# 6           1000.0
# 7           1000.0

# %%
bios.head(8)  ##No changes will be made to original dataset
# Out:
#     age     sex     bmi  children smoker     region      charges  new_charges
# 0  19.0  female  27.900       0.0    yes  southwest  16884.92400  21884.92400
# 1  18.0    male  33.770       1.0     no  southeast   1725.55230   2725.55230
# 2  28.0    male  33.000       3.0     no  southeast   4449.46200   5449.46200
# 3  33.0    male  22.705       0.0     no  northwest  21984.47061  22984.47061
# 4  32.0    male  28.880       0.0     no  northwest   3866.85520   4866.85520
# 5  31.0  female  25.740       0.0     no  southeast   3756.62160   4756.62160
# 6  46.0  female  33.440       1.0     no  southeast   8240.58960   9240.58960
# 7  37.0  female  27.740       3.0     no  northwest   7281.50560   8281.50560

# %%
## renaming column in copy dataset  (changes are not permanent,by using inplace changes are made permanent)
data_backup.rename(columns={'sex':'gender'},inplace=True)

# %%
data_backup.head(7)
# Out:
#     age  gender     bmi  children smoker     region      charges  new_charges  \
# 0  19.0  female  27.900       0.0    yes  southwest  16884.92400  21884.92400
# 1  18.0    male  33.770       1.0     no  southeast   1725.55230   2725.55230
# 2  28.0    male  33.000       3.0     no  southeast   4449.46200   5449.46200
# 3  33.0    male  22.705       0.0     no  northwest  21984.47061  22984.47061
# 4  32.0    male  28.880       0.0     no  northwest   3866.85520   4866.85520
# 5  31.0  female  25.740       0.0     no  southeast   3756.62160   4756.62160
# 6  46.0  female  33.440       1.0     no  southeast   8240.58960   9240.58960
#
#    diff_in_charges
# 0           5000.0
# 1           1000.0
# 2           1000.0
# 3           1000.0
# 4           1000.0
# 5           1000.0
# 6           1000.0

# %%
# Using lambda expression to change the value

bios_new=bios.copy()
bios_new.head(5)
# Out:
#     age     sex     bmi  children smoker     region      charges  new_charges
# 0  19.0  female  27.900       0.0    yes  southwest  16884.92400  21884.92400
# 1  18.0    male  33.770       1.0     no  southeast   1725.55230   2725.55230
# 2  28.0    male  33.000       3.0     no  southeast   4449.46200   5449.46200
# 3  33.0    male  22.705       0.0     no  northwest  21984.47061  22984.47061
# 4  32.0    male  28.880       0.0     no  northwest   3866.85520   4866.85520

# %%
bios_new['age']=bios_new['age'].apply(lambda x: 'young' if x<25 else 'older' )

# %%
bios_new      #check the difference between the age column in above and below one
# Out:
#         age     sex     bmi  children smoker     region      charges  \
# 0     young  female  27.900       0.0    yes  southwest  16884.92400
# 1     young    male  33.770       1.0     no  southeast   1725.55230
# 2     older    male  33.000       3.0     no  southeast   4449.46200
# 3     older    male  22.705       0.0     no  northwest  21984.47061
# 4     older    male  28.880       0.0     no  northwest   3866.85520
# ...     ...     ...     ...       ...    ...        ...          ...
# 2768  young  female  34.600       0.0     no  southwest   2020.17700
# 2769  young    male  26.030       1.0    yes  northwest  16450.89470
# 2770  young    male  18.715       0.0     no  northwest  21595.38229
# 2771  older    male  31.600       0.0     no  southwest   9850.43200
# Row1  young     NaN     NaN       NaN    NaN        NaN          NaN
#
#       new_charges
# 0     21884.92400
# 1      2725.55230
# 2      5449.46200
# 3     22984.47061
# 4      4866.85520
# ...           ...
# ...

# %%
# bios_new.drop("Row1",inplace=True)  # Got executed already so results in error
bios_new.tail(5)
# Out:
#         age     sex     bmi  children smoker     region      charges  \
# 2768  young  female  34.600       0.0     no  southwest   2020.17700
# 2769  young    male  26.030       1.0    yes  northwest  16450.89470
# 2770  young    male  18.715       0.0     no  northwest  21595.38229
# 2771  older    male  31.600       0.0     no  southwest   9850.43200
# Row1  young     NaN     NaN       NaN    NaN        NaN          NaN
#
#       new_charges
# 2768   3020.17700
# 2769  21450.89470
# 2770  22595.38229
# 2771  10850.43200
# Row1          NaN

# %%
bios.tail(2)
# Out:
#        age   sex   bmi  children smoker     region   charges  new_charges
# 2771  54.0  male  31.6       0.0     no  southwest  9850.432    10850.432
# Row1  20.0   NaN   NaN       NaN    NaN        NaN       NaN          NaN

# %%
bios_new=bios.copy()

# %%
bios_new.fillna(0,inplace=True)

# %%
bios_new.tail(5)    # mainly for Row1 which has the values as NaN
# Out:
#        age     sex     bmi  children smoker     region      charges  \
# 2768  21.0  female  34.600       0.0     no  southwest   2020.17700
# 2769  19.0    male  26.030       1.0    yes  northwest  16450.89470
# 2770  23.0    male  18.715       0.0     no  northwest  21595.38229
# 2771  54.0    male  31.600       0.0     no  southwest   9850.43200
# Row1  20.0       0   0.000       0.0      0          0      0.00000
#
#       new_charges
# 2768   3020.17700
# 2769  21450.89470
# 2770  22595.38229
# 2771  10850.43200
# Row1      0.00000

# %%
bios_new['parent']=bios_new['children'].apply(lambda x: 'yes' if x > 0 else 'no')   #Just tried for fun to create a column using lambda exp

# %%
bios_new.sample(10)
# Out:
#        age     sex     bmi  children smoker     region      charges  \
# 831   36.0  female  25.840       0.0     no  northwest   5266.36560
# 306   28.0  female  27.500       2.0     no  southwest  20177.67113
# 1693  30.0  female  33.330       1.0     no  southeast   4151.02870
# 497   45.0    male  28.700       2.0     no  southwest   8027.96800
# 589   38.0  female  30.690       1.0     no  southeast   5976.83110
# 740   45.0    male  24.035       2.0     no  northeast   8604.48365
# 2217  36.0  female  25.840       0.0     no  northwest   5266.36560
# 1164  41.0  female  28.310       1.0     no  northwest   7153.55390
# 1355  45.0  female  25.700       3.0     no  southwest   9101.79800
# 2375  24.0  female  20.520       0.0    yes  northeast  14571.89080
#
#       new_charges parent
# 831    6266.36560     no
# 306   21177.67113    yes
# 1693   5151.02870    yes
# 497    9027.96800    yes
# 589    6976.83110    yes
# 740    9604.48365    yes
# 2217   6266.36560     no
# ...

# %% [markdown]
# # Merge and concatenation

# %%
 """  Done by using merge() and concat()
 for this i need two files unfortunately i don't have other file similar to this dataset  """
# Out:
# "  Done by using merge() and concat()\nfor this i need two files unfortunately i don't have other file similar to this dataset  "

# %% [markdown]
# # Copying specific column using copy()

# %%
male=bios_new[bios_new['sex']=='male'].copy()

# %%
male.head()
# Out:
#     age   sex     bmi  children smoker     region      charges  new_charges  \
# 1  18.0  male  33.770       1.0     no  southeast   1725.55230   2725.55230
# 2  28.0  male  33.000       3.0     no  southeast   4449.46200   5449.46200
# 3  33.0  male  22.705       0.0     no  northwest  21984.47061  22984.47061
# 4  32.0  male  28.880       0.0     no  northwest   3866.85520   4866.85520
# 8  37.0  male  29.830       2.0     no  northeast   6406.41070   7406.41070
#
#   parent
# 1    yes
# 2    yes
# 3     no
# 4     no
# 8    yes

# %%
# Renaming a column using rename()

# bios_new.rename(columns={"sex":"gender"})

# %%
bios_new=bios_new.rename(columns={"sex":"gender"})

# %%
print(bios_new)
# Out:
#        age  gender     bmi  children smoker     region      charges  \
# 0     19.0  female  27.900       0.0    yes  southwest  16884.92400
# 1     18.0    male  33.770       1.0     no  southeast   1725.55230
# 2     28.0    male  33.000       3.0     no  southeast   4449.46200
# 3     33.0    male  22.705       0.0     no  northwest  21984.47061
# 4     32.0    male  28.880       0.0     no  northwest   3866.85520
# ...    ...     ...     ...       ...    ...        ...          ...
# 2768  21.0  female  34.600       0.0     no  southwest   2020.17700
# 2769  19.0    male  26.030       1.0    yes  northwest  16450.89470
# 2770  23.0    male  18.715       0.0     no  northwest  21595.38229
# 2771  54.0    male  31.600       0.0     no  southwest   9850.43200
# Row1  20.0       0   0.000       0.0      0          0      0.00000
#
#       new_charges parent
# 0     21884.92400     no
# 1      2725.55230    yes
# 2      5449.46200    yes
# 3     22984.47061     no
# ...
